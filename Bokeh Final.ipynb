# %%
# Perform necessary imports
from bokeh.io import output_file, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool

import pandas as pd
data = pd.read_csv('gapminder_tidy.csv')
data.set_index('Year')
data.head()
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region
# 0  South Asia
# 1  South Asia
# 2  South Asia
# 3  South Asia
# 4  South Asia

# %%
# Perform necessary imports
from bokeh.io import output_file, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool

import pandas as pd
data = pd.read_csv('gapminder_tidy.csv')
data.set_index('Year')
data.head()

# Make the ColumnDataSource: source
source = ColumnDataSource(data={
    'x'       : data.loc[1970].fertility ,
    'y'       : data.loc[1970].life ,
    'country' : data.loc[1970].Country ,
})

# Create the figure: p
p = figure(title='1970', x_axis_label='Fertility (children per woman)', y_axis_label='Life Expectancy (years)',
           plot_height=400, plot_width=700,
           tools=[HoverTool(tooltips='@country')])

# Add a circle glyph to the figure p
p.circle(x='x', y='y', source=source)

# Output the file and show the figure
output_file('gapminder.html')
show(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-26d1e7a3be65> in <module>()
#      13     'x'       : data.loc[1970].fertility ,
#      14     'y'       : data.loc[1970].life ,
# ---> 15     'country' : data.loc[1970].Country ,
#      16 })
#      17
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\models\sources.py in __init__(self, *args, **kw)
#     157         super(ColumnDataSource, self).__init__(**kw)
#     158         self.column_names[:] = list(raw_data.keys())
# --> 159         self.data.update(raw_data)
#     160
#     161     @staticmethod
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\property\containers.py in wrapper(self, *args, **kwargs)
#      79         old = self._saved_copy()
#      80         result = func(self, *args, **kwargs)
# ---> 81         self._notify_owners(old)
#      82         return result
#      83     wrapper.__doc__ = "Container method ``%s`` instrumented to notify property owners" % func.__name__
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\property\containers.py in _notify_owners(self, old, hint)
#     106     def _notify_owners(self, old, hint=None):
#     107         for (owner, prop) in self._owners:
# --> 108             prop._notify_mutated(owner, old, hint)
#     109
#     110     def _saved_copy(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\property\descriptors.py in _notify_mutated(self, obj, old, hint)
#     811         # re-validate because the contents of 'old' have changed,
#     812         # in some cases this could give us a new object for the value
# --> 813         value = self.property.prepare_value(obj, self.name, value)
#     814
#     815         self._real_set(obj, old, value, hint)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\property\bases.py in prepare_value(self, obj_or_cls, name, value)
#     288                     break
#     289             else:
# --> 290                 raise e
#     291         else:
#     292             value = self.transform(value)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\property\bases.py in prepare_value(self, obj_or_cls, name, value)
#     281     def prepare_value(self, obj_or_cls, name, value):
#     282         try:
# --> 283             self.validate(value)
#     284         except ValueError as e:
#     285             for tp, converter in self.alternatives:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\properties.py in validate(self, value)
#    1257             if not (isinstance(value, dict) and \
#    1258                     all(self.keys_type.is_valid(key) and self.values_type.is_valid(val) for key, val in iteritems(value))):
# -> 1259                 raise ValueError("expected an element of %s, got %r" % (self, value))
#    1260
#    1261     def _sphinx_type(self):
#
# ValueError: expected an element of ColumnData(String, Seq(Any)), got {'x': 6.7939999999999996, 'y': 46.834000000000003, 'country': 'Congo, Dem. Rep.'}
